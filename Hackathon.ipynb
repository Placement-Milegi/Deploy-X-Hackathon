# %% [markdown]
# CLASSIFICATION :
# 1. DATA COLLECTION
# 2. DATA PREPROCESS
# 3. NORMALISATION
# 4. MODEL SELECTION
# 5. DATA SPLITTING
# 6. TRAIN-TEST-VALIDATION
# 7. PERFORMANCE ANALYSIS
# 8. MODEL SAVING

# %% [markdown]
# DATA COLLECTION :-

# %%
import pandas as pd
# Out:
# Running cells with 'Python 3.13.12' requires the ipykernel package.
#
# <a href='command:jupyter.createPythonEnvAndSelectController'>Create a Python Environment</a> with the required packages.
#
# Or install 'ipykernel' using the command: 'c:/Users/NITRO/AppData/Local/Microsoft/WindowsApps/python3.13.exe -m pip install ipykernel -U --user --force-reinstall'

# %%
df=pd.read_csv('/StudentPerformanceFactors.csv')

# %%
df.info()

# %% [markdown]
# DATA PREPROCESSING :-

# %%
df.head(10)

# %%
df = df.drop_duplicates()

# %%
df = df.dropna()

# %% [markdown]
# NORMALISATION :-

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(12, 5))
df['Hours_Studied'].value_counts().plot(kind='bar')
plt.xlabel('Access_to_Resources')
plt.ylabel('Count')
plt.title('Access_to_Resources')
plt.show()

# %%
plt.figure(figsize=(12, 5))
df['Attendance'].value_counts().plot(kind='bar')
plt.xlabel('Status')
plt.ylabel('count')
plt.title('Attendance')
plt.show()

# %%
plt.figure(figsize=(12, 5))
df['Parental_Involvement'].value_counts().plot(kind='bar')
plt.xlabel('status')
plt.ylabel('Count')
plt.title('Parental_Involvement')
plt.show()

# %%
plt.figure(figsize=(12, 5))
df['Access_to_Resources'].value_counts().plot(kind='bar')
plt.xlabel('Access_to_Resources')
plt.ylabel('Count')
plt.title('Access_to_Resources')
plt.show()

# %%
plt.figure(figsize=(12, 5))
df['Extracurricular_Activities'].value_counts().plot(kind='bar')
plt.xlabel('Status')
plt.ylabel('Count')
plt.title('Extracurricular_Activities')
plt.show()

# %%
plt.figure(figsize=(12, 5))
df['Sleep_Hours'].value_counts().plot(kind='bar')
plt.xlabel('Status')
plt.ylabel('Count')
plt.title('Sleep_Hours')
plt.show()

# %%
plt.figure(figsize=(12, 5))
df['Previous_Scores'].value_counts().plot(kind='bar')
plt.xlabel('Status')
plt.ylabel('Count')
plt.title('Previous_Scores')
plt.show()

# %%
plt.figure(figsize=(12, 5))
df['Motivation_Level'].value_counts().plot(kind='bar')
plt.xlabel('Status')
plt.ylabel('Count')
plt.title('Motivation_Level')
plt.show()

# %%
plt.figure(figsize=(12, 5))
df['Internet_Access'].value_counts().plot(kind='bar')
plt.xlabel('Status')
plt.ylabel('Count')
plt.title('Internet_Access')
plt.show()

# %%
plt.figure(figsize=(12, 5))
df['Tutoring_Sessions'].value_counts().plot(kind='bar')
plt.xlabel('Status')
plt.ylabel('Count')
plt.title('Tutoring_Sessions')
plt.show()

# %%
plt.figure(figsize=(12, 5))
df['Family_Income'].value_counts().plot(kind='bar')
plt.xlabel('Status')
plt.ylabel('Count')
plt.title('Family_Income')
plt.show()

# %%
plt.figure(figsize=(12, 5))
df['Teacher_Quality'].value_counts().plot(kind='bar')
plt.xlabel('Status')
plt.ylabel('Count')
plt.title('Teacher_Quality')
plt.show()

# %%
plt.figure(figsize=(12, 5))
df['School_Type'].value_counts().plot(kind='bar')
plt.xlabel('Status')
plt.ylabel('Count')
plt.title('School_Type')
plt.show()

# %%
plt.figure(figsize=(12, 5))
df['Peer_Influence'].value_counts().plot(kind='bar')
plt.xlabel('Status')
plt.ylabel('Count')
plt.title('Peer_Influence')
plt.show()

# %%
plt.figure(figsize=(12, 5))
df['Physical_Activity'].value_counts().plot(kind='bar')
plt.xlabel('Status')
plt.ylabel('Count')
plt.title('Physical_Activity')
plt.show()

# %%
plt.figure(figsize=(12, 5))
df['Learning_Disabilities'].value_counts().plot(kind='bar')
plt.xlabel('Status')
plt.ylabel('Count')
plt.title('Learning_Disabilities')
plt.show()

# %%
plt.figure(figsize=(12, 5))
df['Exam_Score'].value_counts().plot(kind='bar')
plt.xlabel('Status')
plt.ylabel('Count')
plt.title('Exam_Score')
plt.show()

# %% [markdown]
# DATA SPLITING :-

# %%
X = df.drop('Exam_Score',axis=1)
Y = df['Exam_Score']

# %%
X.head()

# %%
Y.head()

# %% [markdown]
# TRAIN-TEST-SPLIT :-

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X,Y,test_size=0.2,random_state=42)

# %% [markdown]
# MODEL TRAINING :-

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report

# %%
df_clf = DecisionTreeClassifier()
df_clf.fit(X_train,Y_train)

# %%
df_pred = df_clf.predict(X_test)
df_acc = accuracy_score(Y_test,df_pred)
print(df_acc)

# %%
df_rf = RandomForestClassifier()
df_rf.fit(X_train,Y_train)

# %%
df_pred = df_rf.predict(X_test)
df_acc = accuracy_score(Y_test,df_pred)
print(df_acc)

# %% [markdown]
# MODEL SAVING :-

# %%
import pickle
with open('df_model.pkl', 'wb') as file:
    pickle.dump(df_rf, file)
print("Model saved successfully")
